# %% [markdown]
# <a href="https://colab.research.google.com/github/steph123564/jupyter/blob/main/Untitled122/5/23.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly.express as px 
pd.set_option("display.max_columns", 200)
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel("Desarrollo.xlsx")

# %%
df.shape
# Out:
# (135, 74)

# %%
df
# Out:
#              Marca temporal  Edad Género                    Puesto  \
# 0   2023-03-25 13:22:43.713    34   Ella            Data Scientist
# 1   2023-03-25 13:27:58.625    28   Ella  Especialista de datos JR
# 2   2023-03-25 13:29:57.996    27     El            Data Scientist
# 3   2023-03-25 13:30:36.546    27     El              Data Analyst
# 4   2023-03-25 13:30:50.955    23   Ella              Data Analyst
# ..                      ...   ...    ...                       ...
# 130 2023-04-01 07:21:26.348    50     El             Data Engineer
# 131 2023-04-01 07:57:07.081    37     El            Data Scientist
# 132 2023-04-01 11:18:46.780    35     El         Android engineer
# 133 2023-04-03 18:14:29.454    29   Ella          Dynamic pricing
# 134 2023-04-03 22:26:03.674    26     El           PO Arquitectura
#
#      Años de experiencia en la industria tech Salario bruto actual (mensual)  \
# 0                                         9.0                         81-90K
# ...
